# %% [markdown]
# <a href="https://colab.research.google.com/github/p77549646-boop/INTMI2025M/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Digite um número: "))

if numero > 10:
  print("O número é maior que 10")
else:
  print("O número não é maior que 10")
# Out:
# Digite um número: 25
# O número é maior que 10

# %%
numero = int(input("Digite um número:" ))
if numero % 2 == 0 and numero % 2 == 0:
  print("O número é par e divisível por 2")
else:
  print("O número não é par e divisível por 2")
# Out:
# digite um numero:24
# o numero é par e divisivel por 2

# %%
nome = input("Digite um nome: ")

if "a" in nome.lower():
  print(f"O nome '{nome}' contém a letra 'a'.")
else:
  print(f"O nome '{nome}' não contém a letra 'a'.")
# Out:
# Digite um nome: Paulo
# O nome 'Paulo' contém a letra 'a'.

# %%
numero = int(input("Digite um número: "))

if numero % 5 == 0:
  print("O número é múltiplo de 5.")
else:
  print("O número não é múltiplo de 5.")
# Out:
# Digite um número: 55
# O número é múltiplo de 5.

# %%
temperatura = float(input("Digite a temperatura atual em °C: "))

if temperatura > 30:
  print("Está quente.")
else:
  print("Está frio.")
# Out:
# Digite a temperatura atual em °C: 39
# Está quente.

# %%
opcao = input("Digite 'S' para continuar ou 'N' para sair: ")

if opcao.upper() == "S":
  print("Você escolheu continuar.")
elif opcao.upper() == "N":
  print("Você escolheu sair.")
else:
  print("Opção inválida.")
# Out:
# Digite 'S' para continuar ou 'N' para sair: s
# Você escolheu continuar.

# %%
numero = float(input("Digite um número: "))

if numero > 0:
  print("O número é positivo.")
elif numero < 0:
  print("O número é negativo.")
else:
  print("O número é zero.")
# Out:
# Digite um número: 7243727
# O número é positivo.

# %%
numero_dia = int(input("Digite um número de 1 a 7: "))

if numero_dia == 1:
  print("Domingo")
elif numero_dia == 2:
  print("Segunda-feira")
elif numero_dia == 3:
  print("Terça-feira")
elif numero_dia == 4:
  print("Quarta-feira")
elif numero_dia == 5:
  print("Quinta-feira")
elif numero_dia == 6:
  print("Sexta-feira")
elif numero_dia == 7:
  print("Sábado")
else:
  print("Número inválido. Digite um número de 1 a 7.")
# Out:
# Digite um número de 1 a 7: 6
# Sexta-feira

# %%
ano = int(input("Digite um ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
  print(f"O ano {ano} é bissexto.")
else:
  print(f"O ano {ano} não é bissexto.")
# Out:
# Digite um ano: 2010
# O ano 2010 não é bissexto.

# %%
horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas: "))
valor_por_hora = float(input("Digite o valor por hora: "))

if horas_trabalhadas <= 40:
  salario = horas_trabalhadas * valor_por_hora
  print(f"O salário é de R${salario:.2f}")
else:
  horas_normais = 40
  horas_extras = horas_trabalhadas - horas_normais
  salario_normal = horas_normais * valor_por_hora
  salario_extra = horas_extras * valor_por_hora * 1.5
  salario_total = salario_normal + salario_extra
  print(f"O salário é de R${salario_total:.2f}")
# Out:
# Digite a quantidade de horas trabalhadas: 2435
# Digite o valor por hora: 0.0001
# O salário é de R$0.36

# %% [markdown]
# # ESTRURA DE REPETIÇÃO
#
# ## for in range
#
# repete uma estrutrura de codigo N vezes que sera determinado por um contador(x,i, ou outra variavel).
# Ex:

# %%
cont = 0
for cont in range(1
                01):
  print ("contador" , cont)
# Out:
#   File "/tmp/ipython-input-4290267730.py", line 3
#     01):
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# Crie um algoritimo que receba um numero do usuario e imprima a tabuada de o ate 10

# %%
numero = int(input("digite um numero: "))
for i in range(11):
  resultado = numero * i
  print(f"{numero} x {i} = {resultado}")
# Out:
# digite um numero: 9079807
# 9079807 x 0 = 0
# 9079807 x 1 = 9079807
# 9079807 x 2 = 18159614
# 9079807 x 3 = 27239421
# 9079807 x 4 = 36319228
# 9079807 x 5 = 45399035
# 9079807 x 6 = 54478842
# 9079807 x 7 = 63558649
# 9079807 x 8 = 72638456
# 9079807 x 9 = 81718263
# 9079807 x 10 = 90798070

# %%
cont = 0
for cont in range (1000000000001):
 if cont < 5:
  print ("menor")
# Out:
# menor
# menor
# menor
# menor
# menor
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1601347462.py in <cell line: 0>()
#       1 cont = 0
#       2 for cont in range (1000000000001):
# ----> 3  if cont < 5:
#       4   print ("menor")
#
# KeyboardInterrupt:

# %% [markdown]
# ##Estrutura de repetição
#
# for reéte uma estrutura de codigo n vezes

# %% [markdown]
# crie um algoritimo que mostre os numeros pares entre 0 e 200

# %%
for cont in range(201):
  if (cont % 2 == 0):
    print(cont, "é par!")
# Out:
# 0 é par!
# 2 é par!
# 4 é par!
# 6 é par!
# 8 é par!
# 10 é par!
# 12 é par!
# 14 é par!
# 16 é par!
# 18 é par!
# 20 é par!
# 22 é par!
# 24 é par!
# 26 é par!
# 28 é par!
# 30 é par!
# 32 é par!
# 34 é par!
# 36 é par!
# 38 é par!
# 40 é par!
# 42 é par!
# 44 é par!
# 46 é par!
# 48 é par!
# 50 é par!
# 52 é par!
# 54 é par!
# 56 é par!
# 58 é par!
# 60 é par!
# 62 é par!
# 64 é par!
# 66 é par!
# 68 é par!
# 70 é par!
# 72 é par!
# 74 é par!
# 76 é par!
# 78 é par!
# 80 é par!
# 82 é par!
# 84 é par!
# 86 é par!
# 88 é par!
# 90 é par!
# 92 é par!
# 94 é par!
# 96 é par!
# 98 é par!
# 100 é par!
# 102 é par!
# 104 é par!
# 106 é par!
# 108 é par!
# 110 é par!
# 112 é par!
# 114 é par!
# 116 é par!
# 118 é par!
# 120 é par!
# 122 é par!
# 124 é par!
# 126 é par!
# 128 é par!
# 130 é par!
# 132 é par!
# 134 é par!
# 136 é par!
# 138 é par!
# 140 é par!
# 142 é par!
# 144 é par!
# 146 é par!
# 148 é par!
# 150 é par!
# 152 é par!
# 154 é par!
# 156 é par!
# 158 é par!
# 160 é par!
# 162 é par!
# 164 é par!
# 166 é par!
# 168 é par!
# 170 é par!
# 172 é par!
# 174 é par!
# 176 é par!
# 178 é par!
# 180 é par!
# 182 é par!
# 184 é par!
# 186 é par!
# 188 é par!
# 190 é par!
# 192 é par!
# 194 é par!
# 196 é par!
# 198 é par!
# 200 é par!

# %% [markdown]
# ##while - enquanto
#
# repete uma estrutura ate a condição ser atingida

# %%
numero = 0

while(numero < 10):
 print ("menor que 10")
 numero = int(input("digite um numero: "))

print("maior ou igual a 10")
# Out:
# menor que 10
# digite um numero: 99
# maior ou igual a 10

# %% [markdown]
# ## jogo da adivinhação

# %%
import random as rd

# %%
aleatorio = rd.randint(0, 100)

print("=========================================")
print("jogo da adivinhação")
print("=========================================")
print("tente adivinhar o numero que estou pensando!")
print("=========================================")

tentativa = 5

while (tentativa > 0):
  numero = int(input("digite um numero: "))
  if (numero == aleatorio):
    print ("Parabens")
    break
  elif (numero > aleatorio):
    print("digite um numero menor")
  else:
    print("digite um numero maior")
  tentativa -= 1
  if(tentativa == 0):
    print("game over")
# Out:
# =========================================
# jogo da adivinhação
# =========================================
# tente adivinhar o numero que estou pensando!
# =========================================
# digite um numero: 67
# digite um numero menor
# digite um numero: 40
# digite um numero maior
# digite um numero: 50
# digite um numero menor
# digite um numero: 48
# digite um numero menor
# digite um numero: 46
# digite um numero menor
# game over

# %% [markdown]
# ## Calculadora Interativa em Python
#
# Este programa oferece uma calculadora simples e interativa com diversas opções de operações. Ele rodará em um loop contínuo até que você decida sair, exibindo um menu a cada repetição para que você possa escolher a funcionalidade desejada.

# %%
# O programa rodará em um loop infinito (while True) até que o usuário decida sair.
# A opção '0' é usada para interromper o loop com um 'break'.
while True:
    # Exibe o menu principal da calculadora a cada iteração do loop.
    print("\n=========================")
    print("**CALCULADORA INTERATIVA**")
    print("=========================")
    print("Digite o número da opção desejada:")
    print("1 - Múltiplos de 5 em um Intervalo")
    print("2 - Contagem de Números Pares em um Intervalo")
    print("3 - Verificador de Número Primo")
    print("4 - Conversor de Temperatura (Cº para Fº)")
    print("0 - Sair do Programa")

    # Solicita a opção do usuário.
    opcao = input("Sua opção: ")

    # ----- Tratamento das Opções (usando if/elif/else) -----
    if opcao == '0':
        # Se o usuário digitar '0', o programa exibe uma mensagem de despedida e encerra.
        print("\nSaindo do programa. Até mais!")
        break # Interrompe o loop 'while True'

    elif opcao == '1':
        # --- Opção 1: Múltiplos de 5 em um Intervalo ---
        print("\n--- Múltiplos de 5 em um Intervalo ---")
        try:
            # Solicita o início e o fim do intervalo e converte para inteiro.
            inicio = int(input("Digite o número inicial do intervalo: "))
            fim = int(input("Digite o número final do intervalo: "))
            print(f"Múltiplos de 5 entre {inicio} e {fim}:")
            encontrou = False # Flag para verificar se algum múltiplo foi encontrado.

            # Percorre o intervalo (incluindo o 'fim').
            for num in range(inicio, fim + 1):
                # Verifica se o número é divisível por 5 (ou seja, múltiplo de 5).
                if num % 5 == 0:
                    print(num)
                    encontrou = True
            if not encontrou:
                print("Nenhum múltiplo de 5 encontrado no intervalo.")
        except ValueError:
            # Captura erros se o usuário digitar algo que não seja um número inteiro.
            print("Entrada inválida. Por favor, digite números inteiros.")

    elif opcao == '2':
        # --- Opção 2: Contagem de Números Pares em um Intervalo ---
        print("\n--- Contagem de Números Pares em um Intervalo ---")
        try:
            # Solicita o início e o fim do intervalo.
            inicio = int(input("Digite o número inicial do intervalo: "))
            fim = int(input("Digite o número final do intervalo: "))
            count_pares = 0 # Inicializa o contador de números pares.
            print(f"Verificando números pares entre {inicio} e {fim}...")

            # Percorre o intervalo e conta os números pares.
            for num in range(inicio, fim + 1):
                if num % 2 == 0:
                    count_pares += 1
            print(f"Total de números pares encontrados: {count_pares}")
        except ValueError:
            print("Entrada inválida. Por favor, digite números inteiros.")

    elif opcao == '3':
        # --- Opção 3: Verificador de Número Primo ---
        print("\n--- Verificador de Número Primo ---")
        try:
            # Solicita um número inteiro positivo.
            numero = int(input("Digite um número inteiro positivo: "))
            if numero <= 1:
                # Números menores ou iguais a 1 não são primos por definição.
                print(f"O número {numero} não é primo.")
            else:
                eh_primo = True # Assume que é primo até que se prove o contrário.
                # O loop vai de 2 até a raiz quadrada do número (otimização).
                for i in range(2, int(numero**0.5) + 1):
                    if numero % i == 0:
                        # Se encontrar um divisor, não é primo.
                        eh_primo = False
                        break # Sai do loop, pois já sabemos que não é primo.
                if eh_primo:
                    print(f"O número {numero} é primo.")
                else:
                    print(f"O número {numero} não é primo.")
        except ValueError:
            print("Entrada inválida. Por favor, digite um número inteiro.")

    elif opcao == '4':
        # --- Opção 4: Conversor de Temperatura (Cº para Fº) ---
        print("\n--- Conversor de Temperatura (Cº para Fº) ---")
        try:
            # Solicita a temperatura em Celsius e converte para float.
            celsius = float(input("Digite a temperatura em Celsius (Cº): "))
            # Aplica a fórmula de conversão de Celsius para Fahrenheit.
            fahrenheit = (celsius * 9/5) + 32
            print(f"{celsius:.2f} Cº equivalem a {fahrenheit:.2f} Fº.")
        except ValueError:
            print("Entrada inválida. Por favor, digite um número para a temperatura.")

    else:
        # --- Opção Inválida ---
        # Se o usuário digitar algo diferente das opções válidas.
        print("\nOpção inválida. Por favor, escolha uma opção entre 0 e 4.")
# Out:
# =========================
# **CALCULADORA INTERATIVA**
# =========================
# Digite o número da opção desejada:
# 1 - Múltiplos de 5 em um Intervalo
# 2 - Contagem de Números Pares em um Intervalo
# 3 - Verificador de Número Primo
# 4 - Conversor de Temperatura (Cº para Fº)
# 0 - Sair do Programa
# Sua opção: 2
#
# --- Contagem de Números Pares em um Intervalo ---
# Digite o número inicial do intervalo: 0
# Digite o número final do intervalo: 100000
# Verificando números pares entre 0 e 100000...
# Total de números pares encontrados: 50001
#
# =========================
# **CALCULADORA INTERATIVA**
# =========================
# Digite o número da opção desejada:
# 1 - Múltiplos de 5 em um Intervalo
# 2 - Contagem de Números Pares em um Intervalo
# 3 - Verificador de Número Primo
# 4 - Conversor de Temperatura (Cº para Fº)
# 0 - Sair do Programa
# Sua opção: 0
#
# Saindo do programa. Até mais!

# %% [markdown]
# ### Como Usar:
#
# 1.  **Execute a célula de código acima.**
# 2.  O menu da calculadora será exibido.
# 3.  **Digite o número da opção desejada** (0, 1, 2, 3 ou 4) e pressione `Enter`.
# 4.  Siga as instruções para cada opção.
# 5.  Para sair, digite `0`.
